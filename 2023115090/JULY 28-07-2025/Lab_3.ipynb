# %% [markdown]
# # Task
# Implement K-Nearest Neighbors (KNN) classification and its types, evaluate performance for different K values, and integrate basic MLOps steps for reproducibility and tracking using the Iris dataset from sklearn.datasets.

# %% [markdown]
# ## Load and prepare the data
#
# ### Subtask:
# Load the Iris dataset from `sklearn.datasets`, split it into training and testing sets, and scale the features.

# %% [markdown]
# **Reasoning**:
# The subtask requires loading and splitting the Iris dataset, followed by scaling the features. These steps can be combined into a single code block.

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

iris = load_iris()
X_train, X_test, y_train, y_test = train_test_split(iris.data, iris.target, test_size=0.2, random_state=42, stratify=iris.target)

scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %% [markdown]
# ## Implement knn and evaluate
#
# ### Subtask:
# Implement KNN classification, evaluate its performance for different K values, and plot the results.

# %% [markdown]
# **Reasoning**:
# Implement KNN classification, evaluate its performance for different K values, and plot the results as instructed.

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score
import matplotlib.pyplot as plt

k_values = range(1, 21)
accuracy_scores = []

for k in k_values:
    knn = KNeighborsClassifier(n_neighbors=k)
    knn.fit(X_train_scaled, y_train)
    y_pred = knn.predict(X_test_scaled)
    accuracy = accuracy_score(y_test, y_pred)
    accuracy_scores.append(accuracy)

plt.figure(figsize=(10, 6))
plt.plot(k_values, accuracy_scores, marker='o')
plt.title('KNN Accuracy vs. K Value')
plt.xlabel('Number of Neighbors (K)')
plt.ylabel('Accuracy')
plt.xticks(k_values)
plt.grid(True)
plt.show()

# %% [markdown]
# ## Integrate mlops
#
# ### Subtask:
# Log the parameters and metrics for each run using MLflow.

# %% [markdown]
# **Reasoning**:
# Import the mlflow library and loop through the k values, logging the parameter k and the accuracy for each run.

# %%
import mlflow

k_values = range(1, 21)
accuracy_scores = []

for k in k_values:
    with mlflow.start_run():
        knn = KNeighborsClassifier(n_neighbors=k)
        knn.fit(X_train_scaled, y_train)
        y_pred = knn.predict(X_test_scaled)
        accuracy = accuracy_score(y_test, y_pred)
        accuracy_scores.append(accuracy)

        mlflow.log_param("k", k)
        mlflow.log_metric("accuracy", accuracy)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipython-input-3354754450.py in <cell line: 0>()
# ----> 1 import mlflow
#       2
#       3 k_values = range(1, 21)
#       4 accuracy_scores = []
#       5
#
# ModuleNotFoundError: No module named 'mlflow'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %% [markdown]
# **Reasoning**:
# Install the missing mlflow library using pip.

# %%
# !pip install mlflow
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 25.8/25.8 MB 71.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 70.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 57.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 247.0/247.0 kB 19.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 147.8/147.8 kB 12.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.9/114.9 kB 8.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.0/85.0 kB 7.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 688.0/688.0 kB 42.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 203.4/203.4 kB 15.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.6/65.6 kB 5.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 120.0/120.0 kB 9.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 201.6/201.6 kB 13.5 MB/s eta 0:00:00
# ...

# %% [markdown]
# **Reasoning**:
# Now that mlflow is installed, repeat the previous code block to import mlflow and log the parameters and metrics for each run.

# %%
import mlflow

k_values = range(1, 21)
accuracy_scores = []

for k in k_values:
    with mlflow.start_run():
        knn = KNeighborsClassifier(n_neighbors=k)
        knn.fit(X_train_scaled, y_train)
        y_pred = knn.predict(X_test_scaled)
        accuracy = accuracy_score(y_test, y_pred)
        accuracy_scores.append(accuracy)

        mlflow.log_param("k", k)
        mlflow.log_metric("accuracy", accuracy)

# %% [markdown]
# ## Summary:
#
# ### Data Analysis Key Findings
#
# *   The Iris dataset was successfully loaded, split into training and testing sets with stratified sampling (80/20 split), and the features were scaled using `StandardScaler`.
# *   K-Nearest Neighbors (KNN) models were trained and evaluated for K values ranging from 1 to 20 on the scaled data.
# *   The accuracy of the KNN model varied with the value of K, and these accuracies were successfully logged along with their corresponding K values using MLflow.
#
# ### Insights or Next Steps
#
# *   Review the MLflow runs to identify the optimal K value that yielded the highest accuracy on the test set.
# *   Explore other classification algorithms and compare their performance to the best-performing KNN model using consistent evaluation metrics and MLflow tracking.
