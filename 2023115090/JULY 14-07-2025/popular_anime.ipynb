# %% [markdown]
# ##*This is a csv file from Kaggle (credits where credits due) from this dataset the following conclusions and models to be created and made.*
#
# ##TASKS :
#
# - 🧠 1. Predict Anime Popularity
# Build a regression model to predict an anime's rating or popularity score using features like genre, number of episodes, or airing date.
# from sklearn.linear_model import LinearRegression
#  or try RandomForestRegressor, XGBoost, etc.
#
#  💡 Bonus: Try feature engineering! Convert genres into one-hot encoded vectors or extract airing season/year for better predictions.
#
# - 🎭 2. Genre Classification
# Train a model to classify anime into genres based on plot summaries (if available) or user reviews using NLP techniques.
# from sklearn.feature_extraction.text import TfidfVectorizer
# from sklearn.naive_bayes import MultinomialNB
#
#  💬 You can even fine-tune a transformer (like BERT) if you're up for a deep learning twist.
#
# - 🌟 3. Recommendation System
# Suggest new anime to users based on what they like. Use collaborative filtering, content-based filtering, or hybrid approaches.
# from sklearn.metrics.pairwise import cosine_similarity. Try matrix factorization methods, or use Surprise library
#
#  👥 If user ratings are included, it's perfect for building personalized recommendations.
#
# - 🧪 4. Clustering and Similarity Analysis
# Group similar anime titles together using unsupervised learning like K-Means or DBSCAN.
# from sklearn.cluster import KMeans
#
#  📌 Great for exploring patterns among anime based on tags, length, or scores.
#
# - 📊 5. Exploratory Data Analysis
# Before diving into modeling, build gorgeous visualizations:
#  - Most common genres
#  - Rating distributions
#  - Trends by year/season

# %%
# Task 1 :
# Goal : Predict Anime Popularity
# Consequence : regression model to predict an anime's rating or popularity score using features like genre, number of episodes, or airing date.
# from sklearn.linear_model import LinearRegression
#  or try RandomForestRegressor, XGBoost, etc.

# %% [markdown]
# #Dataset Loading

# %%
import kagglehub

path = kagglehub.dataset_download("bhavyadhingra00020/top-anime-dataset-2024")

print("Path to dataset files:", path)
# Out:
# ...
# 100%|██████████| 459k/459k [00:00<00:00, 57.4MB/s]
# Extracting files...
# Path to dataset files: /root/.cache/kagglehub/datasets/bhavyadhingra00020/top-anime-dataset-2024/versions/2

# %%
import pandas as pd

data = pd.read_csv('/root/.cache/kagglehub/datasets/bhavyadhingra00020/top-anime-dataset-2024/versions/2/Top_Anime_data.csv')

df = pd.DataFrame(data)

print(df.columns)
# Out:
# Index(['Score', 'Popularity', 'Rank', 'Members', 'Description', 'Synonyms',
#        'Japanese', 'English', 'Type', 'Episodes', 'Status', 'Aired',
#        'Premiered', 'Broadcast', 'Producers', 'Licensors', 'Studios', 'Source',
#        'Genres', 'Demographic', 'Duration', 'Rating'],
#       dtype='object')

# %% [markdown]
# ##Checking the columns for any missing data and cleaning it

# %%
for columns in df.columns :
  print(columns, df[columns].isnull().sum())
  print(df[columns].unique())
# Out:
# Score 0
# [9.38 9.09 9.07 9.06 9.05 9.04 9.03 9.02 9.01 8.98 8.94 8.93 8.92 8.91
#  8.9  8.89 8.88 8.87 8.84 8.82 8.81 8.79 8.78 8.77 8.76 8.75 8.74 8.73
#  8.72 8.71 8.7  8.69 8.68 8.67 8.66 8.65 8.64 8.63 8.62 8.61 8.6  8.59
#  8.58 8.57 8.56 8.55 8.54 8.53 8.52 8.51 8.5  8.49 8.48 8.47 8.46 8.45
#  8.44 8.43 8.42 8.41 8.4  8.39 8.38 8.37 8.36 8.35 8.34 8.33 8.32 8.31
#  8.3  8.29 8.28 8.27 8.26 8.25 8.24 8.23 8.22 8.21 8.2  8.19 8.18 8.17
#  8.16 8.15 8.14 8.13 8.12 8.11 8.1  8.09 8.08 8.07 8.06 8.05 8.04 8.03
#  8.02 8.01 8.   7.99 7.98 7.97 7.96 7.95 7.94 7.93 7.92 7.91 7.9  7.89
#  7.88 7.87 7.86 7.85 7.84 7.83 7.82 7.81 7.8 ]
# Popularity 0
# [  284     3    13   342    21  1532     9   393   411   746   738   178
#    473   761   140   118    20   609   567    46  1006   329  1399  1213
#    131   574   357   184    11  2032   359  1137   386    72    35  3426
#    117   920   487    44   368   102   306    88  3851    43    75  2725
# ...

# %% [markdown]
# ##looking at the values

# %%
col = ['Episodes', 'Aired', 'Genres', 'Duration', 'Demographic', 'Source']

for columns in col :
  print(columns, df[columns].isnull().sum())
  print(df[columns].unique())
# Out:
# Episodes 0
# ['28' '64' '24' '51' '10' '1' '148' '13' '110' '12' '201' '22' '25' '2'
#  '14' '74' '7' '23' '26' '16' '75' '11' '47' 'Unknown' '4' '43' '27' '37'
#  '39' '101' '8' '99' '112' '6' '62' '120' '15' '50' '20' '17' '33' '40'
#  '79' '94' '3' '500' '52' '78' '77' '96' '291' '70' '38' '170' '203' '237'
#  '104' '63' '102' '21' '130' '49' '5' '45' '103' '220' '153' '109' '34'
#  '9' '366' '54' '145' '18' '69' '36' '178' '167' '60' '373' '1787' '113'
#  '35' '155']
# Aired 0
# ['Sep 29, 2023 to Mar 22, 2024' 'Apr 5, 2009 to Jul 4, 2010'
#  'Apr 6, 2011 to Sep 14, 2011' 'Apr 8, 2015 to Mar 30, 2016'
#  'Apr 29, 2019 to Jul 1, 2019' 'Jan 8, 2021' 'Oct 2, 2011 to Sep 24, 2014'
#  'Apr 4, 2011 to Mar 26, 2012' 'Oct 11, 2022 to Dec 27, 2022'
#  'Jan 8, 1988 to Mar 17, 1997' 'Oct 4, 2012 to Mar 28, 2013'
#  'Apr 9, 2022 to Jun 25, 2022' 'Apr 6, 2021 to Jun 29, 2021'
#  'Jan 9, 2017 to Mar 27, 2017' 'Apr 4, 2006 to Mar 25, 2010'
#  'Oct 3, 2008 to Mar 27, 2009' 'Sep 17, 2016'
# ...

# %% [markdown]
# ##selective preprocessing

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder
from sklearn.impute import SimpleImputer
